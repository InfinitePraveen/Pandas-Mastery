# %%
# 1. Load the elections.csv from the Berkeley notebook .
import pandas as pd

df = pd.read_csv('elections.csv')
df
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# 4    54.574789
# ..         ...
# 177   1.073699
# 178  51.311515
# 179  46.858542
# 180   1.177979
# 181   0.255731
#
# [182 rows x 6 columns]

# %%
# 2. Select all rows where the candidate's name is "Andrew Jackson" using boolean masking.
mask = df['Candidate'] == 'Andrew Jackson'
filtered_df = df[mask]
filtered_df
# Out:
#    Year       Candidate                  Party  Popular vote Result          %
# 0  1824  Andrew Jackson  Democratic-Republican        151271   loss  57.210122
# 2  1828  Andrew Jackson             Democratic        642806    win  56.203927
# 4  1832  Andrew Jackson             Democratic        702735    win  54.574789

# %%
# 3. Select the Year and % columns for all rows where the result was "win".
win_columns = df['Result'] == 'win'
filtered_win_columns = df[win_columns]
columns = ['Year', '%']
filtered_win_columns = filtered_win_columns[columns]

filtered_win_columns
# Out:
#      Year          %
# 1    1824  42.789878
# 2    1828  56.203927
# 4    1832  54.574789
# 8    1836  52.272472
# 11   1840  53.051213
# 13   1844  50.749477
# 16   1848  47.309296
# 17   1852  51.013168
# 20   1856  45.306080
# 23   1860  39.699408
# 27   1864  54.951512
# 30   1868  52.665305
# 32   1872  55.928594
# 33   1876  48.471624
# 36   1880  48.369234
# 39   1884  48.884933
# 43   1888  47.858041
# 47   1892  46.121393
# 53   1896  51.213817
# 56   1900  52.342640
# 60   1904  56.562787
# 65   1908  52.013300
# 70   1912  41.933422
# 74   1916  49.367987
# 79   1920  60.574501
# 80   1924  54.329113
# 84   1928  58.368524
# 86   1932  57.672125
# 91   1936  60.978107
# 94   1940  54.871202
# 97   1944  53.773801
# 100  1948  49.601536
# 106  1952  55.325173
# 109  1956  57.650654
# 111  1960  50.082561
# 114  1964  61.344703
# 117  1968  43.565246
# 120  1972  60.907806
# 123  1976  50.271900
# 131  1980  50.897944
# 133  1984  59.023326
# 135  1988  53.518845
# 140  1992  43.118485
# 144  1996  49.296938
# 152  2000  47.974666
# 157  2004  50.771824
# 162  2008  53.023510
# 168  2012  51.258484
# 173  2016  46.407862
# 178  2020  51.311515

# %%
# 4. Use iloc to extract the last 5 rows of the DataFrame.

print(df.iloc[-5:])
# Out:
#      Year       Candidate        Party  Popular vote Result          %
# 177  2016      Jill Stein        Green       1457226   loss   1.073699
# 178  2020    Joseph Biden   Democratic      81268924    win  51.311515
# 179  2020    Donald Trump   Republican      74216154   loss  46.858542
# 180  2020    Jo Jorgensen  Libertarian       1865724   loss   1.177979
# 181  2020  Howard Hawkins        Green        405035   loss   0.255731

# %%
# 5. Use loc to extract rows 1828 through 1836 (you may need to inspect the Year column).

# 1. Set the Year column as the index (if it's not already)
df_indexed = df.set_index('Year')

# 2. Slice using .loc (Note: Use integers if the Year column contains numbers, or strings if it's text)
df_indexed.loc[1828:1836]
# Out:
#                    Candidate                Party  Popular vote Result  \
# Year
# 1828          Andrew Jackson           Democratic        642806    win
# 1828       John Quincy Adams  National Republican        500897   loss
# 1832          Andrew Jackson           Democratic        702735    win
# 1832              Henry Clay  National Republican        484205   loss
# 1832            William Wirt         Anti-Masonic        100715   loss
# 1836       Hugh Lawson White                 Whig        146109   loss
# 1836        Martin Van Buren           Democratic        763291    win
# 1836  William Henry Harrison                 Whig        550816   loss
#
#               %
# Year
# 1828  56.203927
# 1828  43.796073
# 1832  54.574789
# 1832  37.603628
# 1832   7.821583
# 1836  10.005985
# 1836  52.272472
# 1836  37.721543
